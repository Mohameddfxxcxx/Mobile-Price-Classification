# %% [markdown]
# # Introduction

# %% [markdown]
# Navigating the ever-expanding sea of mobile phones in today's market can feel like diving into a whirlpool of choices 📱💸. With each device boasting its own array of features and price tags, finding the perfect match for your needs and budget can be quite the challenge. Fear not, though, for the tide is turning in your favor!
#
# Welcome to a project set to revolutionize your smartphone selection process. We're diving deep into the realm of machine learning to develop a powerful model 🤖 that can categorize mobile phones into distinct price ranges based on their unique features. Say goodbye to the confusion of endless spec comparisons and hello to informed decisions! 🎉
#
# Join us on this journey as we navigate the waves of innovation to bring clarity and confidence to your mobile phone purchasing experience. 🌊

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Set sail on a quest to conquer the chaos of smartphone shopping with our mission at hand! 🚀📱 Picture this: a world where you can effortlessly find your perfect phone match amidst the sea of options. Our challenge? Crafting a cutting-edge predictive model that acts as your trusty navigator, seamlessly classifying mobile devices into their rightful price brackets based on a treasure trove of attributes. From battery power to camera prowess, memory to connectivity, we're delving deep into the data to unearth the ultimate smartphone gems! 💎
#
# Fear not, fellow adventurers! Armed with a dataset brimming with mobile phone details and their corresponding price tags, we're on the brink of revolutionizing your tech quest. Join us as we harness the power of machine learning to chart a course towards smartphone serenity, where confusion is banished and clarity reigns supreme! 🌟

# %%
import pandas as pd  # Importing the pandas library for data manipulation and analysis
import matplotlib.pyplot as plt  # Importing the matplotlib library for data visualization
import seaborn as sns  # Importing the seaborn library for enhanced data visualization
import warnings  # Importing the warnings module to suppress any potential warnings during code execution
warnings.filterwarnings("ignore")  # Ignoring any warnings to prevent them from being displayed during execution

# %%
train=pd.read_csv("train.csv")  # Loading the training dataset from a CSV file into a pandas DataFrame named 'train'
test=pd.read_csv("test.csv")    # Loading the testing dataset from a CSV file into a pandas DataFrame named 'test'

# %%
pd.set_option('display.max_rows',None)    # Setting the option to display all rows of a DataFrame without truncation
pd.set_option('display.max_columns',None)  # Setting the option to display all columns of a DataFrame without truncation

# %% [markdown]
# # Dataset Description

# %% [markdown]
# Dive into the digital ocean of smartphone specs! Here's the treasure map to our dataset riches: 🗺️
#
# battery_power: Total energy stored in mAh 🔋
#
# blue: Bluetooth capability (1 for yes, 0 for no) 📶
#
# clock_speed: Processor execution speed ⏱️
#
# dual_sim: Dual SIM support (1 for yes, 0 for no) 📲
#
# fc: Front Camera resolution in megapixels 📸
#
# four_g: 4G network support (1 for yes, 0 for no) 📶
#
# int_memory: Internal Memory in gigabytes 💾
#
# m_dep: Mobile Depth in centimeters 📏
#
# mobile_wt: Weight of the mobile phone in grams ⚖️
#
# n_cores: Number of processor cores 🔢
#
# pc: Primary Camera resolution in megapixels 📷
#
# px_height: Pixel Resolution Height 📏
#
# px_width: Pixel Resolution Width 📐
#
# ram: Random Access Memory in megabytes 🧠
#
# sc_h: Screen Height in centimeters 📏
#
# sc_w: Screen Width in centimeters 📐
#
# talk_time: Battery talk time ⏰
#
# three_g: 3G network support (1 for yes, 0 for no) 📶
#
# touch_screen: Touch screen support (1 for yes, 0 for no) ✋
#
# wifi: WiFi connectivity (1 for yes, 0 for no) 📶
#
# price_range: Price range (0 for low cost, 1 for medium cost, 2 for high cost, 3 for very high cost) 💰
#
# Embark on your journey through the realm of smartphones with these enchanted attributes guiding your way! 🚀📱

# %%
train.head()  # Displaying the first few rows of the 'train' DataFrame to get a glimpse of the dataset
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
test.head()   # Displaying the first few rows of the testing dataset to get an overview of its structure and contents
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193        3  16        226      1412  3476    12     7
# 1    0.8        191        5  12        746       857  3895     6     0
# 2    0.9        186        3   4       1270      1366  2396    17    10
# 3    0.5         96        8  20        295      1752  3893    10     0
# 4    0.5        108        6  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test.drop('id',axis=1,inplace=True)  # Dropping the 'id' column from the testing dataset along the columns (axis=1) and modifying the dataset in place

# %%
test.head()  # Displaying the first few rows of the modified testing dataset after dropping the 'id' column
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  16        226      1412  3476    12     7          2
# 1        191        5  12        746       857  3895     6     0          7
# 2        186        3   4       1270      1366  2396    17    10         10
# 3         96        8  20        295      1752  3893    10     0          7
# 4        108        6  18        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# In the quest for the perfect machine learning model, data reigns supreme! 📊✨ After embarking on a grand voyage of inspection, we're thrilled to report that our dataset is a treasure trove of completeness! 🏴‍☠️🔍 No missing values to be found, no outliers lurking in the shadows – just pure, balanced data waiting to be unleashed upon the world! 🌟💼
#
# Our journey doesn't stop there! A feast for the eyes awaits as we delve into the realm of data visualization, confirming what our hearts already know: our data is as balanced as a seasoned tightrope walker! 🎨📊 Let the visual spectacle commence, guiding us toward the shores of model mastery! 🌊🚀

# %%
sns.countplot(train['price_range'])  # Creating a count plot using seaborn to visualize the distribution of the 'price_range' column in the training dataset
# Out:
# <Axes: ylabel='count'>

# %%
price_counts = train['price_range'].value_counts()  # Counting the occurrences of each unique value in the 'price_range' column and storing the result in the variable 'price_counts'
plt.pie(price_counts, labels=price_counts.index, autopct='%1.1f%%')  # Creating a pie chart to visualize the distribution of price ranges using Matplotlib, with labels and percentage formatting
plt.title('Price Range Distribution')  # Adding a title to the pie chart
plt.show()  # Displaying the pie chart

# %%
train.shape,test.shape 
# Displaying the shape (number of rows and columns) of the training dataset
# Displaying the shape (number of rows and columns) of the testing dataset
# Out:
# ((2000, 21), (1000, 20))

# %% [markdown]
# Behold the wondrous spectacle of our data visualization, revealing a landscape untouched by the blight of missing values! 🌟🔍 Like a star-studded sky on a clear night, our dataset sparkles with completeness, leaving no room for shadows of doubt. 🌌✨ Let this visual feast serve as a testament to the purity of our data, a beacon guiding us toward the shores of machine learning glory! 🚀📊

# %%
train.isnull().sum()  # Checking for missing values in the training dataset by calculating the sum of null values for each column
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
train.info()  # Displaying concise summary information about the training dataset, including the data types of each column and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.describe()  # Generating descriptive statistics of the numerical columns in the training dataset, such as count, mean, standard deviation, minimum, maximum, and quartiles
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
train.columns  # Accessing the column names of the training dataset, providing a list of all columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
train.plot(kind='box',figsize=(20,10))  # Creating a box plot to visualize the distribution and spread of numerical values in the training dataset, with a specified figure size for better visibility
# Out:
# <Axes: >

# %%
colors = {0: 'red',1: 'blue', 2: 'green', 3:'purple'}  # Defining colors for different price ranges

plt.scatter(train['price_range'],train['ram'], c=train['price_range'].apply(lambda x: colors[x]))  # Creating a scatter plot to visualize the relationship between 'price_range' and 'ram', with each point colored according to its price range
plt.xlabel('Price Range')  # Adding label for the x-axis
plt.ylabel('RAM')  # Adding label for the y-axis
plt.xticks([0, 1, 2, 3])  # Setting the x-axis ticks
plt.show()  # Displaying the scatter plot

# %% [markdown]
# In the enchanted realm of machine learning, behold the wondrous correlation heatmap! 🌟🔥 This mystical visualization unveils the intricate dance of relationships between our dataset's features, illuminating pathways to understanding and enlightenment. 📊✨
#
# As we gaze upon its colorful tapestry, we uncover the secrets of correlation: values nearing 1 signal a harmonious bond, while those nearing -1 reveal a captivating dance of opposites. And lo, where values hover near 0, we find a realm untouched by the ties of correlation. 🎭💫
#
# With this sacred knowledge in hand, analysts and data sorcerers alike are empowered to unlock the mysteries of feature selection, guide the winds of data preprocessing, and unravel the enigma of model interpretation! 🔍💡
#
# Our journey yields a revelation: a shining beacon amidst the correlations, where price range and RAM stand hand in hand, their bond unbreakable. RAM emerges as a titan among features, a key player in the grand saga of estimating price range! 🚀🔑

# %%
correlation = train.corr()  # Calculating the correlation matrix of the training dataset, showcasing the relationships between its features

plt.figure(figsize=[20, 15])  # Setting the size of the heatmap figure for better visualization
sns.heatmap(correlation, cmap='viridis', annot=True, annot_kws={'fontsize':10})  # Creating a heatmap using seaborn to visualize the correlation matrix, with annotations and custom font size
plt.show()  # Displaying the heatmap

# %% [markdown]
# # Training and Testing

# %% [markdown]
# In the grand tale of data science, the Train/Test divide marks a crucial chapter, where the dataset is split asunder into two realms: 🚂🔍
#
# The Training Kingdom, where our model learns the secrets of the data, encompassing 80% of its vast expanse. 📚🔮
#
# The Testing Dominion, a realm of trials and tribulations, embracing the remaining 20% to put our model's newfound knowledge to the test. 🧪🏰
#
# Thus, our journey unfolds, with the Training Kingdom nurturing the growth of our model's wisdom, while the Testing Dominion stands as the ultimate crucible, where its true strength shall be revealed! 💪🔥

# %%
X = train.drop('price_range',axis=1)  # Creating a feature matrix X by removing the 'price_range' column from the training dataset
y = train['price_range']  # Creating a target vector y containing the 'price_range' column values from the training dataset

# %%
from sklearn.model_selection import train_test_split  # Importing the train_test_split function from the sklearn library for splitting the dataset into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100, test_size=0.2)  # Splitting the feature matrix X and target vector y into training and testing sets, with 80% for training and 20% for testing, using a random state for reproducibility
print(X_train.shape, X_test.shape)  # Printing the shapes of the training and testing sets to confirm the split
# Out:
# (1600, 20) (400, 20)

# %% [markdown]
# # Model Build

# %% [markdown]
# In the intricate dance of algorithm selection, the data reigns supreme, guiding our path toward the perfect match! 🛤️💡 Depending on the unique tapestry of our data and the enigma we seek to solve, we embark on a quest to choose the most fitting algorithm, forging a bond between data and model that shall stand the test of time! ⚔️📊
#
# Enter the humble decision tree: a beacon of clarity in the fog of complexity! 🌳🔍 As a non-parametric wonder, it beckons both classification and regression tasks with open arms, its hierarchical structure unfolding like a map to the stars! 🌌✨ With its roots firmly planted in the soil of data, each node becomes a gatekeeper to knowledge, each branch a path to understanding, and each leaf a testament to wisdom gained! 🍃🔮

# %%
from sklearn.tree import DecisionTreeClassifier  # Importing the DecisionTreeClassifier class from the sklearn library

dt = DecisionTreeClassifier()  # Creating an instance of the DecisionTreeClassifier class

dt.fit(X_train, y_train)  # Training the decision tree classifier on the training data (X_train and y_train)

y_pred_dt = dt.predict(X_test)  # Making predictions on the test data using the trained decision tree classifier

# %% [markdown]
# In the enchanted forest of machine learning, the Random Forest stands tall as a majestic guardian, comprised of a legion of decision trees united in purpose! 🌳🌲 With the power of bagging and the whimsy of feature randomness, it weaves a tapestry of diversity in its leafy canopy, fending off the specter of overfitting and beckoning accuracy to its side! 🎩🔮 As each tree whispers its own tale, the forest as a whole becomes a sanctuary of knowledge and a fortress of wisdom, ready to guide us through the wilderness of data! 🏞️🌟

# %%
from sklearn.ensemble import RandomForestClassifier  # Importing the RandomForestClassifier class from the sklearn library

rf = RandomForestClassifier()  # Creating an instance of the RandomForestClassifier class

rf.fit(X_train, y_train)  # Training the random forest classifier on the training data (X_train and y_train)

y_pred_rf = rf.predict(X_test)  # Making predictions on the test data using the trained random forest classifier

# %% [markdown]
# In the realm of machine learning, behold the mighty XGBoost! 🌟🚀 This champion among algorithms is no mere tree but a towering colossus of extreme gradient boosted trees, where each tree stands as a sentinel, correcting the errors of its predecessors and paving the way to enlightenment! 🌳🔥 With each layer added, the ensemble grows stronger, weaving a tapestry of resilience and adaptability that propels us to new heights of predictive power! 🎢💥 So let us harness the energy of XGBoost, riding the waves of gradient descent to conquer the peaks of accuracy and forge a path to victory! 🏆🌈

# %%
# !pip install xgboost
from xgboost import XGBClassifier  # Importing the XGBClassifier class from the xgboost library

xgb = XGBClassifier()  # Creating an instance of the XGBClassifier class

xgb.fit(X_train, y_train)  # Training the XGBoost classifier on the training data (X_train and y_train)

y_pred_xgb = xgb.predict(X_test)  # Making predictions on the test data using the trained XGBoost classifier
# Out:
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 435.7 kB/s eta 0:03:49
#    ---------------------------------------- 0.1/99.8 MB 550.5 kB/s eta 0:03:02
#    ---------------------------------------- 0.1/99.8 MB 804.6 kB/s eta 0:02:04
# ...

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# In the grand arena of model evaluation, Accuracy emerges as a shining beacon of success, illuminating the path to greatness! 🌟🔍 This noble metric measures the harmony between our model's predictions and the ground truth, revealing the proportion of triumphs amidst the trials of evaluation! 🏆💡 As a steadfast companion on our journey, Accuracy stands ready to assess the prowess of our classification model, especially in the serene waters where classes are balanced and victory lies within reach! 🚀🎯 Let us embrace this metric with open arms, as we strive for excellence in the realm of machine learning! 🌟📊

# %%
from sklearn.metrics import confusion_matrix  # Importing the confusion_matrix function from the sklearn.metrics module for evaluating the classification model's performance

from sklearn.metrics import accuracy_score  # Importing the accuracy_score function from the sklearn.metrics module for calculating the accuracy of the classification model

# %%
dt_acc = accuracy_score(y_pred_dt, y_test)  # Calculating the accuracy score of the Decision Tree Classifier Algorithm by comparing the predicted labels (y_pred_dt) with the actual labels from the test set (y_test)

print("Accuracy score of Decision Tree Classifier Algorithm is: ", dt_acc)  # Printing the accuracy score of the Decision Tree Classifier Algorithm

print(confusion_matrix(y_pred_dt,y_test))  # Printing the confusion matrix to evaluate the performance of the Decision Tree Classifier Algorithm
# Out:
# Accuracy score of Decision Tree Classifier Algorithm is:  0.795
# [[89  8  0  0]
#  [11 75 14  0]
#  [ 0 16 70 21]
#  [ 0  0 12 84]]

# %%
rf_acc = accuracy_score(y_pred_rf, y_test)  # Calculating the accuracy score of the Random Forest Classifier Algorithm by comparing the predicted labels (y_pred_rf) with the actual labels from the test set (y_test)

print("Accuracy score of Random Forest Classifier Algorithm is: ", rf_acc)  # Printing the accuracy score of the Random Forest Classifier Algorithm

print(confusion_matrix(y_pred_rf,y_test))  # Printing the confusion matrix to evaluate the performance of the Random Forest Classifier Algorithm
# Out:
# Accuracy score of Random Forest Classifier Algorithm is:  0.8625
# [[93 10  0  0]
#  [ 7 76 12  0]
#  [ 0 13 77  6]
#  [ 0  0  7 99]]

# %%
xgb_acc = accuracy_score(y_pred_xgb, y_test)  # Calculating the accuracy score of the XGBoost Classifier Algorithm by comparing the predicted labels (y_pred_xgb) with the actual labels from the test set (y_test)

print("Accuracy score of XGBoost Classifier Algorithm is: ", xgb_acc)  # Printing the accuracy score of the XGBoost Classifier Algorithm

print(confusion_matrix(y_pred_xgb,y_test))  # Printing the confusion matrix to evaluate the performance of the XGBoost Classifier Algorithm
# Out:
# Accuracy score of XGBoost Classifier Algorithm is:  0.8925
# [[ 94   7   0   0]
#  [  6  85   9   0]
#  [  0   7  78   5]
#  [  0   0   9 100]]

# %%
plt.bar(x=['dtc','rfc','xgb'],height=[dt_acc,rf_acc,xgb_acc])  # Creating a bar plot to visualize the accuracy scores of different algorithms
plt.xlabel("Algorithms")  # Adding label for the x-axis
plt.ylabel("Accuracy Score")  # Adding label for the y-axis
plt.show()  # Displaying the bar plot

# %% [markdown]
# # Conclusion

# %% [markdown]
# In our quest to decode the secrets of mobile price classification, we embarked on a journey with three valiant companions: the Decision Tree Classifier, the Random Forest Classifier, and the mighty XGBoost Classifier! 📱🌟 Through the lens of accuracy, we beheld their prowess and gleaned insights into their performance.
#
# In the grand arena of algorithms, it was XGBoost that emerged victorious, wielding an accuracy score of 90 percent like a shining beacon of hope! 🚀🏆 Our mission, noble and true, is to empower consumers with the knowledge they need to navigate the labyrinth of mobile phone choices within their budgetary bounds. 🛒💰
#
# But our tale does not end there! These findings hold untold value for manufacturers and retailers, offering glimpses into the minds of consumers and the ever-shifting currents of market trends. 📈🔍 Let us forge ahead, armed with insights and determination, as we illuminate the path toward informed decisions and brighter tomorrows! 💡🌈
